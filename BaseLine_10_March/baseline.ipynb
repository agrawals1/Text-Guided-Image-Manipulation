# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# %cd base
os.getcwd()
# Out:
# /home2/bagler/content/ImgMan/base
# '/home2/bagler/content/ImgMan/base'

# %%
from main_script import main

# %%
model = 'styleganinv_ffhq256'
text = 'she has red hair and blue lips'
clip_loss_wt = 2.0
lr = 0.01
iterations = 500
img_path = "./examples/test1.png"

# %%
main(model, text, lr, iterations, clip_loss_wt, img_path)
# Out:
# [2023-03-09 20:32:38,618][INFO] Build network for module `generator` in model `styleganinv_ffhq256`.
# [2023-03-09 20:32:38,848][INFO] Loading pytorch weights from `models/pretrain/styleganinv_ffhq256_generator.pth`.
# [2023-03-09 20:32:38,930][INFO] Successfully loaded!
# [2023-03-09 20:32:40,887][INFO] Current `lod` is 0.0.
# [2023-03-09 20:32:40,889][INFO] Build network for module `encoder` in model `styleganinv_ffhq256`.
# [2023-03-09 20:32:41,829][INFO] Loading pytorch weights from `models/pretrain/styleganinv_ffhq256_encoder.pth`.
# [2023-03-09 20:32:42,407][INFO] Successfully loaded!
# loss_pix: 0.031, loss_feat: 2826.574, loss_reg: 0.036, loss_clip: 0.493, loss: 1

# %%
org_img = cv2.imread('results/inversion/test/test1_org.png')
invrt_img = cv2.imread('results/inversion/test/test1_encode.png')
man_img = cv2.imread('results/inversion/test/test1_invert.png')
result = np.hstack([org_img, invrt_img, man_img])

# %%
# %matplotlib inline
plt.figure(figsize=(20,20))
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()
